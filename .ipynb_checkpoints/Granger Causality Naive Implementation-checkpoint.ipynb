# %% [markdown]
# <br>
# <br>
#  <center> <font size = "6"> Granger Causality
#  </font></center>
#
#  <br>
#
#   <center> <font size = "5"> Naive Implementation
#  </font></center>
#  <br>
#  <img src = 'data:image/jpeg;base64,...'  width="160">
# <br>
# <br>
#
# ---

# %% [markdown]
# ### Imports

# %%
from statsmodels.tsa.stattools import grangercausalitytests
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# <br>
#
# ### Simple Example with stats library - two time series
#
# In this exampe we tried to use the grangercausalitytests library from stats model and produce an initial example with Bivariate Granger Causality. Specifically we create a random time series (t1) and a scaled version of it (t2). Subsequently, we adjust the time series  by shifting t2 1 timestamp into the future in  order to 'create' a Granger Caused relationship of t1 -> t2 as also shown in the graph below. Finally, we execute a Granger Causality test for both:
# - t1 -> t2
# - t2 -> t1
#
# using the grangercausalitytests. The Null hypothesis for grangercausalitytests is that the time series in the second column, does NOT Granger cause the time series in the first column. We reject the null hypothesis that x2 does not Granger cause x1 if the pvalues are below a desired size of the test.

# %%
# Build the time series, just a simple AR(1)
# -----------------------------------------
t1 = [0.001*np.random.normal()]
for _ in range(100):
    t1.append(0.5*t1[-1] + 0.1*np.random.normal())
    
# Build the time series that is granger caused by t1, use the t1 scaled x10
t2 = [item*2  for item in t1]

# Adjust t1 and t2, shift t2 1 month into the future
# t1 -> t2
t1 = t1[1:]
t2 = t2[:-1]

# Plot time series
plt.figure(figsize=(10,4))
plt.plot(t1, color='b')
plt.plot(t2, color='r')
plt.legend(['t1', 't2'], fontsize=16)
plt.show()

print('Test for t1 -> t2')
ts_df = pd.DataFrame(columns=['t2', 't1'], data=zip(t2,t1))
ts_df.head()

gc_res = grangercausalitytests(ts_df, [1])

print('')
print('')
print('Test for t2 -> t1')
ts_df = pd.DataFrame(columns=['t1', 't2'], data=zip(t1,t2))
ts_df.head()

gc_res = grangercausalitytests(ts_df, [1])
# Out:
# Test for t1 -> t2
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=388736607122694698822203212824576.0000, p=0.0000  , df_denom=96, df_num=1
# ssr based chi2 test:   chi2=400884626095278919419396131651584.0000, p=0.0000  , df=1
# likelihood ratio test: chi2=6977.1346, p=0.0000  , df=1
# parameter F test:         F=388736607122694626764609174896640.0000, p=0.0000  , df_denom=96, df_num=1
#
#
# Test for t2 -> t1
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.3968  , p=0.2402  , df_denom=96, df_num=1
# ssr based chi2 test:   chi2=1.4405  , p=0.2301  , df=1
# likelihood ratio test: chi2=1.4301  , p=0.2317  , df=1
# parameter F test:         F=1.3968  , p=0.2402  , df_denom=96, df_num=1

# %% [markdown]
# <br>
#
# ### Naive Implementation of Bivariate Granger Causality for more time series
#
# At this point we tried to use this implementation in order to identify Granger Causality relationships from a bigger set of time series. In order to test that our implementation works, we decided to produce a set of three different time series. Specifically, we created two time series t1 and t2 in a way that t1 -> t2 with a lag = 1 and a third (t3) which was entirely random. Using our implementation below we will try to check whether it will manage to capture the t1 -> t2 relationship. We will base our results on p value of the F test with an a=0.05.

# %%
# Build the two granger caused time series
# ----------------------------------------

t1 = [0.001*np.random.normal()]
for _ in range(100):
    t1.append(0.5*t1[-1] + 0.1*np.random.normal())
    
# Build the time series that is granger caused by t1, use the t1 scaled x10
t2 = [item*3  for item in t1]

# Adjust t1 and t2, shift t2 1 month into the future
# t1 -> t2
t1 = t1[1:]
t2 = t2[:-1]

# Build the t3 (random one)
# -------------------------
t3 = [0.001*np.random.normal()]
for _ in range(99):
    t3.append(0.5*t3[-1] + 0.1*np.random.normal())
    
    
# Plot time series
plt.figure(figsize=(10,4))
plt.plot(t1, color='b')
plt.plot(t2, color='r')
plt.plot(t3, color='g')
plt.legend(['t1', 't2', 't3','t4','t5'], fontsize=16)
plt.show()

# %%
# Create the set with the time series data
time_series = [t1, t2, t3]

# Define the lag value
lag = 1

# Initialise the list with the results
results = []

# %%
for i in range(0,len(time_series)):
    for j in range(0,len(time_series)):
        if i!=j:
            print('t'+str(j+1)+'->'+'t'+str(i+1))
    
            X = time_series[i]
            Y = time_series[j]
            
            # Make the Granger Causality Test
            ts_df = pd.DataFrame(columns=['X', 'Y'], data=zip(X,Y))
            gc_res = grangercausalitytests(ts_df, [lag])
            p = gc_res[1][0]['params_ftest'][1]
            if p < 0.005:
                results.append('t'+str(j+1)+'->'+'t'+str(i+1))
            
print('')
print('The Granger Causalities found are:')
print(results)
# Out:
# t2->t1
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.4628  , p=0.4980  , df_denom=96, df_num=1
# ssr based chi2 test:   chi2=0.4772  , p=0.4897  , df=1
# likelihood ratio test: chi2=0.4761  , p=0.4902  , df=1
# parameter F test:         F=0.4628  , p=0.4980  , df_denom=96, df_num=1
# t3->t1
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.5235  , p=0.4711  , df_denom=96, df_num=1
# ssr based chi2 test:   chi2=0.5398  , p=0.4625  , df=1
# likelihood ratio test: chi2=0.5384  , p=0.4631  , df=1
# parameter F test:         F=0.5235  , p=0.4711  , df_denom=96, df_num=1
# t1->t2
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=70023078137427705446137512067072.0000, p=0.0000  , df_denom=96, df_num=1
# ssr based chi2 test:   chi2=72211299329222318426579542212608.0000, p=0.0000  , df=1
# likelihood ratio test: chi2=6807.4409, p=0.0000  , df=1
# parameter F test:         F=70023078137427705446137512067072.0000, p=0.0000  , df_denom=96, df_num=1
# t3->t2
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0367  , p=0.8484  , df_denom=96, df_num=1
# ssr based chi2 test:   chi2=0.0379  , p=0.8457  , df=1
# likelihood ratio test: chi2=0.0379  , p=0.8457  , df=1
# parameter F test:         F=0.0367  , p=0.8484  , df_denom=96, df_num=1
# t1->t3
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.3245  , p=0.2526  , df_denom=96, df_num=1
# ssr based chi2 test:   chi2=1.3659  , p=0.2425  , df=1
# likelihood ratio test: chi2=1.3566  , p=0.2441  , df=1
# parameter F test:         F=1.3245  , p=0.2526  , df_denom=96, df_num=1
# t2->t3
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.3489  , p=0.2484  , df_denom=96, df_num=1
# ssr based chi2 test:   chi2=1.3910  , p=0.2382  , df=1
# likelihood ratio test: chi2=1.3814  , p=0.2399  , df=1
# parameter F test:         F=1.3489  , p=0.2484  , df_denom=96, df_num=1
#
# The Granger Causalities found are:
# ['t1->t2']

# %% [markdown]
# <br>
#
# ### Naive Implementation of Bivariate Granger Causality FMRI data

# %%
df = pd.read_csv ('fmri_timeseries.csv')

# %%
results = []

for i in range(0,len(df.columns)):
    for j in range(0,len(df.columns)):
        if i!=j:
            
            X = df.iloc[: , [i]][df.iloc[: , [i]].columns.values[0]].tolist()
            Y = df.iloc[: , [j]][df.iloc[: , [j]].columns.values[0]].tolist()
            
            # Make the Granger Causality Test
            ts_df = pd.DataFrame(columns=['X', 'Y'], data=zip(X,Y))
            gc_res = grangercausalitytests(ts_df, [lag],verbose=False)
            p = gc_res[1][0]['params_ftest'][1]
            if p < 0.0001:
                results.append(df.iloc[: , [j]].columns.values[0]+'->'+ df.iloc[: , [i]].columns.values[0])
            
print('')
print('The Granger Causalities found are:')
print(results)
# Out:
# The Granger Causalities found are:
# ['LAng->LCau', 'LMTG->LCau', 'RCau->LThal', 'RAntPHG->LThal', 'RAmy->LThal', 'LMTG->LSupraM', 'RAntPHG->LPostPHG', 'LParaCing->APHG', 'RParaCing->APHG', 'RCau->LParaCing', 'LMTG->LPCC', 'LPrec->LPCC', 'RParaCing->LPCC', 'LAng->RPut', 'LSupraM->RPut', 'LMTG->RPut', 'RCau->RThal', 'RAntPHG->RThal', 'RAmy->RThal', 'RParaCing->RAng', 'LPostPHG->RHip', 'RMTG->RHip', 'LThal->RAntPHG', 'LPostPHG->RAntPHG', 'LPostPHG->RAmy', 'LMTG->RPCC']

# %%
results
# Out:
# ['LAng->LCau',
#  'LMTG->LCau',
#  'RCau->LThal',
#  'RAntPHG->LThal',
#  'RAmy->LThal',
#  'LMTG->LSupraM',
#  'RAntPHG->LPostPHG',
#  'LParaCing->APHG',
#  'RParaCing->APHG',
#  'RCau->LParaCing',
#  'LMTG->LPCC',
#  'LPrec->LPCC',
#  'RParaCing->LPCC',
#  'LAng->RPut',
#  'LSupraM->RPut',
#  'LMTG->RPut',
#  'RCau->RThal',
#  'RAntPHG->RThal',
#  'RAmy->RThal',
#  'RParaCing->RAng',
#  'LPostPHG->RHip',
#  'RMTG->RHip',
#  'LThal->RAntPHG',
#  'LPostPHG->RAntPHG',
#  'LPostPHG->RAmy',
#  'LMTG->RPCC']

# %%
### Results from java implementation
>>"LAng"->"LCau"
>>"LMTG"->"LCau"
>>"RCau"->"LThal"
>>"RAntPHG"->"LThal"
>>"RAmy"->"LThal"
>>"LMTG"->"LSupraM"
>>"RAntPHG"->"LPostPHG"
>>"LParaCing"->"APHG"
>>"RParaCing"->"APHG"
>>"RCau"->"LParaCing"
>>"LMTG"->"LPCC"
>>"LPrec"->"LPCC"
>>"RParaCing"->"LPCC"
>>"LAng"->"RPut"
>>"LSupraM"->"RPut"
>>"LMTG"->"RPut"
>>"RCau"->"RThal"
>>"RAntPHG"->"RThal"
>>"RAmy"->"RThal"
>>"RParaCing"->"RAng"
>>"LPostPHG"->"RHip"
>>"RMTG"->"RHip"
>>"LThal"->"RAntPHG"
>>"LPostPHG"->"RAntPHG"
>>"LPostPHG"->"RAmy"
>>"LMTG"->"RPCC"
